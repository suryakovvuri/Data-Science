# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
#value counts of each columns

# %%
df.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, dtype: int64

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
#342 people have survived, 549 dead

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#577 are male and 314 are female

# %%
df.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#class 1 - 216 people
#class 2 - 184 people
#class 3 - 491 people

# %%
df.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 30.00    25
# 28.00    25
# 19.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 27.00    18
# 35.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 23.00    15
# 34.00    15
# 33.00    15
# 20.00    15
# 39.00    14
# 17.00    13
# 40.00    13
# 42.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 47.00     9
#          ..
# 28.50     2
# 40.50     2
# 63.00     2
# 13.00     2
# 10.00     2
# 45.50     2
# 70.00     2
# 30.50     2
# 71.00     2
# 59.00     2
# 57.00     2
# 55.00     2
# 0.75      2
# 64.00     2
# 23.50     1
# 14.50     1
# 0.67      1
# 53.00     1
# 0.92      1
# 0.42      1
# 70.50     1
# 36.50     1
# 80.00     1
# 66.00     1
# 74.00     1
# 12.00     1
# 55.50     1
# 34.50     1
# 24.50     1
# 20.50     1
# Name: Age, dtype: int64

# %%
df.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
#most people dont have sibilings(608)
#209 people have a sibiling

# %%
df.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
df.Cabin.value_counts()
# Out:
# C23 C25 C27        4
# G6                 4
# B96 B98            4
# D                  3
# C22 C26            3
# E101               3
# F2                 3
# F33                3
# B57 B59 B63 B66    2
# C68                2
# B58 B60            2
# E121               2
# D20                2
# E8                 2
# E44                2
# B77                2
# C65                2
# D26                2
# E24                2
# E25                2
# B20                2
# C93                2
# D33                2
# E67                2
# D35                2
# D36                2
# C52                2
# F4                 2
# C125               2
# C124               2
#                   ..
# F G63              1
# A6                 1
# D45                1
# D6                 1
# D56                1
# C101               1
# C54                1
# D28                1
# D37                1
# B102               1
# D30                1
# E17                1
# ...

# %%
#bar graphs

# %%
df.PassengerId.value_counts().plot(kind='hist')

# %%
df.Cabin.value_counts().plot(kind='hist')

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.Age.value_counts().plot(kind='hist')

# %%
df.SibSp.value_counts().plot(kind='hist')

# %%
df.SibSp.value_counts().plot(kind='hist')

# %%
df.Cabin.value_counts().plot(kind='hist')

# %%
df.Embarked.value_counts().plot(kind='hist')

# %%
###missing values
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df[df.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df[df.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
df[df.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex  Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female   38      0      0  113572    80   B28      NaN
# 829  female   62      0      0  113572    80   B28      NaN

# %%
### minimum values
df.Survived.min()
# Out:
# 0

# %%
df.PassengerId.min()
# Out:
# 1

# %%
df.Pclass.min()
# Out:
# 1

# %%
df.Age.min()
# Out:
# 0.41999999999999998

# %%
df.SibSp.min()
# Out:
# 0

# %%
df.Parch.min()
# Out:
# 0

# %%
df.Fare.min()
# Out:
# 0.0

# %%
### max vlaues
df.Survived.max()
# Out:
# 1

# %%
df.PassengerId.max()
# Out:
# 891

# %%
df.Pclass.max()
# Out:
# 3

# %%
df.Age.max()
# Out:
# 80.0

# %%
df.SibSp.max()
# Out:
# 8

# %%
df.Parch.max()
# Out:
# 6

# %%
df.Fare.max()
# Out:
# 512.32920000000001

# %%
### mean values
df.Survived.mean()
# Out:
# 0.3838383838383838

# %%
df.PassengerId.mean()
# Out:
# 446.0

# %%
df.Pclass.mean()
# Out:
# 2.308641975308642

# %%
df.Age.mean()
# Out:
# 29.69911764705882

# %%
df.SibSp.mean()
# Out:
# 0.5230078563411896

# %%
df.Parch.mean()
# Out:
# 0.38159371492704824

# %%
df.Fare.mean()
# Out:
# 32.2042079685746

# %%
### standard deviation
df.Survived.std()
# Out:
# 0.4865924542648585

# %%
df.PassengerId.std()
# Out:
# 257.3538420152301

# %%
df.Pclass.std()
# Out:
# 0.8360712409770513

# %%
df.Age.std()
# Out:
# 14.526497332334044

# %%
df.SibSp.std()
# Out:
# 1.1027434322934275

# %%
df.Parch.std()
# Out:
# 0.8060572211299559

# %%
df.Fare.std()
# Out:
# 49.693428597180905
